# %% [markdown]
# <a href="https://colab.research.google.com/github/Ala-Al-areqi/scientific-computing/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Ala-Al-areqi/scientific-computing.git
# Out:
# fatal: destination path 'scientific-computing' already exists and is not an empty directory.

# %% [markdown]
# # New section

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a
